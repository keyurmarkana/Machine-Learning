# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
c=pd.read_csv('Customers.csv') #get aa data
print(c)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19            15000.0                      39
# 1              2    Male   21                NaN                      81
# 2              3  Female   20            86000.0                       6
# 3              4  Female   23            59000.0                      77
# 4              5  Female   31            38000.0                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71           184387.0                      40
# 1996        1997  Female   91            73158.0                      32
# 1997        1998    Male   87            90961.0                      14
# 1998        1999    Male   77           182109.0                       4
# 1999        2000    Male   90           110610.0                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
print(c.head(10)) #get top 10 records
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19            15000.0                      39
# 1           2    Male   21                NaN                      81
# 2           3  Female   20            86000.0                       6
# 3           4  Female   23            59000.0                      77
# 4           5  Female   31            38000.0                      40
# 5           6  Female   22            58000.0                      76
# 6           7  Female   35            31000.0                       6
# 7           8  Female   23            84000.0                      94
# 8           9    Male   64            97000.0                       3
# 9          10  Female   30            98000.0                      72
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# ...

# %%
cc=c.dropna()
print(cc)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19            15000.0                      39
# 2              3  Female   20            86000.0                       6
# 3              4  Female   23            59000.0                      77
# 4              5  Female   31            38000.0                      40
# 5              6  Female   22            58000.0                      76
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71           184387.0                      40
# 1996        1997  Female   91            73158.0                      32
# 1997        1998    Male   87            90961.0                      14
# 1998        1999    Male   77           182109.0                       4
# 1999        2000    Male   90           110610.0                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
c.sort_values(['Age'],ascending=0)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1103        1104  Female   99           103706.0                      50
# 1524        1525  Female   99           150782.0                      18
# 1629        1630    Male   99           162762.0                      52
# 361          362    Male   99            63364.0                      61
# 1322        1323  Female   99           144176.0                      74
# ...          ...     ...  ...                ...                     ...
# 1271        1272  Female    0            61228.0                      81
# 559          560    Male    0           151298.0                      89
# 1583        1584  Female    0           120899.0                       7
# 211          212  Female    0            22000.0                      92
# 1248        1249  Female    0           143082.0                      63
#
#          Profession  Work Experience  Family Size
# ...

# %%
c.sort_values(['Spending Score (1-100)'],ascending=0)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 680          681    Male   17            96154.0                     100
# 1944        1945    Male   19           129635.0                     100
# 1137        1138    Male   29           118092.0                     100
# 564          565  Female   51           141416.0                     100
# 906          907  Female   17           116463.0                     100
# ...          ...     ...  ...                ...                     ...
# 156          157    Male   37            16000.0                       1
# 391          392    Male    1            89144.0                       1
# 1547        1548  Female   91           107323.0                       1
# 249          250  Female   89            65000.0                       0
# 202          203  Female   16            60000.0                       0
#
#          Profession  Work Experience  Family Size
# ...

# %%
c['Age'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
c.plot("Age",color="blue")
c.plot("Work Experience", color="yellow")
# Out:
# <AxesSubplot:xlabel='Work Experience'>

# %%
c
